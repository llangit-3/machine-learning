# %%
import pandas as pd

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
X = df.drop('Salary', axis=1)
y = df['Salary']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

import numpy as np

# %%
model = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=66)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = model.predict(X_test)

# %%
mse_lin = mean_squared_error(y_test, y_prediction)
rmse_lin = np.sqrt(mse_lin)
r2_lin = r2_score(y_test, y_prediction)

# %%
print(f'MSE: {mse_lin}')
print(f'RMSE: {rmse_lin}')
print(f'R2: {r2_lin}')
# Out:
# MSE: 39034454.15010574
# RMSE: 6247.755929140137
# R2: 0.7782285644532063

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=2)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2)

# %%
y_pred = rf.predict(X_test)

# %%
mse_rf = mean_squared_error(y_test, y_pred)
rmse_rf = np.sqrt(mse_lin)
r2_rf = r2_score(y_test, y_pred)

# %%
print(f'MSE: {mse_rf}')
print(f'RMSE: {rmse_rf}')
print(f'R2: {r2_rf}')
# Out:
# MSE: 19827388.928456362
# RMSE: 6247.755929140137
# R2: 0.8873521200296723

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Weekly_Sales (y_test)')
plt.ylabel('Predicted Weekly_Sales (y_pred)')
plt.show()
